# %% [markdown]
# <a href="https://colab.research.google.com/github/nicksbunny1123/Project-INSE6220-/blob/main/Sample_Project_Classification_with_PyCaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install PyCaret**
#
# PyCaret is an open-source, low-code machine learning library in Python designed to make the end-to-end machine learning process easier and faster for both beginners and experienced data scientists. It offers a variety of tools and functions for data preparation, model training, model selection, and deployment.
#
# pip3 install pycaret==2.3.6 is a command used to install a specific version of the PyCaret library in Python. If you encounter an error message, try running the code again.

# %%
# install slim version (default): if you get an error message, run it again one or more times: 
# !pip3 install pycaret==3.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycaret==3.0.0 in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (7.34.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.6.0)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.2.2)
# Requirement already satisfied: numpy<1.25,>=1.21 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.22.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.7.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.3.7)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.5.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (6.6.0)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.1.0)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.0.3)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.8.3.2)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (7.7.1)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.56.4)
# Requirement already satisfied: tbats>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.1.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.2.1)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (5.13.1)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.27.1)
# Requirement already satisfied: jinja2>=1.2 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.1.2)
# Requirement already satisfied: pyod>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.0.9)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.3.5)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.0.3)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (5.9.5)
# Requirement already satisfied: schemdraw>=0.14 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.16)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.5)
# Requirement already satisfied: kaleido>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.2.1)
# Requirement already satisfied: sktime>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.17.2)
# Requirement already satisfied: scipy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.10.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.2.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.13.5)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.10.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (5.8.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.2.0)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (4.65.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.1.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category-encoders>=2.4.0->pycaret==3.0.0) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation>=2.1.0->pycaret==3.0.0) (23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn>=0.8.1->pycaret==3.0.0) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.12.0->pycaret==3.0.0) (3.15.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.1.6)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (5.7.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (2.14.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (67.7.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.18.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (3.0.7)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (3.6.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (5.5.6)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from lightgbm>=3.0.0->pycaret==3.0.0) (0.40.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (1.4.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.0.0) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.0.0) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.0.0) (5.3.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.0->pycaret==3.0.0) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0,>=1.3.0->pycaret==3.0.0) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->pycaret==3.0.0) (8.2.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (3.8.11)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (0.4.2)
# Requirement already satisfied: trace-updater>=0.0.8 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (0.0.9.1)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.9.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret==3.0.0) (1.26.15)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret==3.0.0) (0.29.34)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pyod>=1.0.8->pycaret==3.0.0) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.0.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.0.0) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.0.0) (2.0.12)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.10/dist-packages (from sktime>=0.16.1->pycaret==3.0.0) (1.2.13)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.2.4)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (5.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret==3.0.0) (1.14.1)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret==3.0.0) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (23.1.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.3.4)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.8.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.5.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret==3.0.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret==3.0.0) (0.2.6)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.4.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->nbformat>=4.2.0->pycaret==3.0.0) (3.3.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.3.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (23.2.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (21.3.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.5.4)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.16.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.17.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (21.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (4.9.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.7.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (4.11.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.8.4)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (2.21)

# %%
#Run the below code in your notebook to check the installed version
from pycaret.utils import version
version()
# Out:
# '3.0.0'

# %% [markdown]
# ## **Principal Component Analysis**
#
# PCA stands for Principal Component Analysis, and it is a widely used technique in data analysis and machine learning for reducing the dimensionality of large datasets. The basic idea behind PCA is to transform a set of high-dimensional variables into a smaller set of uncorrelated variables called principal components, while retaining as much of the original variance as possible.

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
print("Pandas version: ", pd.__version__)
print("Seaborn version: ", sns.__version__)
# Out:
# Pandas version:  1.5.3
# Seaborn version:  0.12.2

# %% [markdown]
# **Dataset**
#
# The examined group comprised kernels belonging to three different varieties of wheat: Kama, Rosa and Canadian, 70 elements each, randomly selected for
# the experiment. High quality visualization of the internal kernel structure was detected using a soft X-ray technique. It is non-destructive and considerably cheaper than other more sophisticated imaging techniques like scanning microscopy or laser technology. The images were recorded on 13x18 cm X-ray KODAK plates. Studies were conducted using combine harvested wheat grain originating from experimental fields, explored at the Institute of Agrophysics of the Polish Academy of Sciences in Lublin.
#
# The data set can be used for the tasks of classification and cluster analysis.
#
#
# Attribute Information:
#
# To construct the data, seven geometric parameters of wheat kernels were measured:
# 1. area A,
# 2. perimeter P,
# 3. compactness C = 4*pi*A/P^2,
# 4. length of kernel,
# 5. width of kernel,
# 6. asymmetry coefficient
# 7. length of kernel groove.
# All of these parameters were real-valued continuous.
#
# https://archive.ics.uci.edu/ml/datasets/seeds

# %% [markdown]
# **Read the dataset**
#
# **pd.read_csv** is a function in the pandas library in Python that is used to read a CSV (Comma Separated Values) file and convert it into a pandas DataFrame.

# %%
#read cvs file into dataframe
df = pd.read_csv('https://raw.githubusercontent.com/nicksbunny1123/Project-INSE6220-/main/auto-mpg.csv')
df.head(25)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0         130    3504          12.0
# 1   15.0          8         350.0         165    3693          11.5
# 2   18.0          8         318.0         150    3436          11.0
# 3   16.0          8         304.0         150    3433          12.0
# 4   17.0          8         302.0         140    3449          10.5
# 5   15.0          8         429.0         198    4341          10.0
# 6   14.0          8         454.0         220    4354           9.0
# 7   14.0          8         440.0         215    4312           8.5
# 8   14.0          8         455.0         225    4425          10.0
# 9   15.0          8         390.0         190    3850           8.5
# 10  15.0          8         383.0         170    3563          10.0
# 11  14.0          8         340.0         160    3609           8.0
# 12  15.0          8         400.0         150    3761           9.5
# 13  14.0          8         455.0         225    3086          10.0
# 14  24.0          4         113.0          95    2372          15.0
# 15  22.0          6         198.0          95    2833          15.5
# 16  18.0          6         199.0          97    2774          15.5
# 17  21.0          6         200.0          85    2587          16.0
# 18  27.0          4          97.0          88    2130          14.5
# 19  26.0          4          97.0          46    1835          20.5
# 20  25.0          4         110.0          87    2672          17.5
# 21  24.0          4         107.0          90    2430          14.5
# 22  25.0          4         104.0          95    2375          17.5
# 23  26.0          4         121.0         113    2234          12.5
# 24  21.0          6         199.0          90    2648          15.0
#
#     model year  Fuel Economy
# 0           70             1
# 1           70             1
# 2           70             1
# 3           70             1
# 4           70             1
# 5           70             1
# 6           70             0
# 7           70             0
# 8           70             0
# 9           70             1
# 10          70             1
# 11          70             0
# 12          70             1
# 13          70             0
# 14          70             1
# 15          70             1
# 16          70             1
# 17          70             1
# 18          70             1
# 19          70             1
# 20          70             1
# 21          70             1
# 22          70             1
# 23          70             1
# 24          70             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    int64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   Fuel Economy  398 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 25.0 KB

# %%
print("Number of duplicated rows is: ", df.duplicated().sum())
# Out:
# Number of duplicated rows is:  0

# %%
print("Number of rows with NaNs is: ", df.isna().any(axis=1).sum())
# Out:
# Number of rows with NaNs is:  0

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# **sns.pairplot** is a function in the seaborn library in Python that is used to plot pairwise relationships between multiple variables in a dataset. The resulting plot is a grid of scatterplots, with each variable plotted against every other variable.

# %%
sns.pairplot(df, hue='Fuel Economy')
plt.show()

# %%
y =df['Fuel Economy']
y.value_counts().plot(kind='pie')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Data Matrix**

# %%
X = df.drop(columns=['Fuel Economy'])
X.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model year
# 0  18.0          8         307.0         130    3504          12.0          70
# 1  15.0          8         350.0         165    3693          11.5          70
# 2  18.0          8         318.0         150    3436          11.0          70
# 3  16.0          8         304.0         150    3433          12.0          70
# 4  17.0          8         302.0         140    3449          10.5          70
# 5  15.0          8         429.0         198    4341          10.0          70
# 6  14.0          8         454.0         220    4354           9.0          70
# 7  14.0          8         440.0         215    4312           8.5          70
# 8  14.0          8         455.0         225    4425          10.0          70
# 9  15.0          8         390.0         190    3850           8.5          70

# %%
X.describe().transpose()
# Out:
#               count         mean         std     min       25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.500    23.0
# cylinders     398.0     5.454774    1.701004     3.0     4.000     4.0
# displacement  398.0   193.425879  104.269838    68.0   104.250   148.5
# horsepower    398.0   104.077889   38.345065    46.0    75.000    92.0
# weight        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5
# acceleration  398.0    15.568090    2.757689     8.0    13.825    15.5
# model year    398.0    76.010050    3.697627    70.0    73.000    76.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   262.000   455.0
# horsepower     125.000   230.0
# weight        3608.000  5140.0
# acceleration    17.175    24.8
# model year      79.000    82.0

# %% [markdown]
# **Standardize the Data**

# %%
Xs = StandardScaler().fit_transform(X)
Xcols = X.columns
X = pd.DataFrame(Xs)
X.columns = Xcols
X.head(10)
# Out:
#         mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0 -0.706439   1.498191      1.090604    0.676873  0.630870     -1.295498
# 1 -1.090751   1.498191      1.503514    1.590786  0.854333     -1.477038
# 2 -0.706439   1.498191      1.196232    1.199109  0.550470     -1.658577
# 3 -0.962647   1.498191      1.061796    1.199109  0.546923     -1.295498
# 4 -0.834543   1.498191      1.042591    0.937991  0.565841     -1.840117
# 5 -1.090751   1.498191      2.262118    2.452475  1.620492     -2.021656
# 6 -1.218855   1.498191      2.502182    3.026935  1.635863     -2.384735
# 7 -1.218855   1.498191      2.367746    2.896376  1.586204     -2.566274
# 8 -1.218855   1.498191      2.511784    3.157494  1.719809     -2.021656
# 9 -1.090751   1.498191      1.887617    2.243581  1.039961     -2.566274
#
#    model year
# 0   -1.627426
# 1   -1.627426
# 2   -1.627426
# 3   -1.627426
# 4   -1.627426
# 5   -1.627426
# 6   -1.627426
# 7   -1.627426
# 8   -1.627426
# 9   -1.627426

# %%
X.describe().transpose()
# Out:
#               count          mean       std       min       25%       50%  \
# mpg           398.0  7.141133e-17  1.001259 -1.859374 -0.770491 -0.065919
# cylinders     398.0 -3.570567e-17  1.001259 -1.444949 -0.856321 -0.856321
# displacement  398.0 -1.785283e-17  1.001259 -1.204411 -0.856318 -0.431404
# horsepower    398.0  1.428227e-16  1.001259 -1.516518 -0.759276 -0.315375
# weight        398.0 -1.606755e-16  1.001259 -1.604943 -0.882827 -0.197362
# acceleration  398.0 -2.677925e-16  1.001259 -2.747814 -0.632879 -0.024722
# model year    398.0 -1.642461e-15  1.001259 -1.627426 -0.815074 -0.002721
#
#                    75%       max
# mpg           0.702705  2.957335
# cylinders     1.498191  1.498191
# displacement  0.658488  2.511784
# horsepower    0.546314  3.288053
# weight        0.753834  2.565185
# acceleration  0.583435  3.351912
# model year    0.809631  1.621983

# %% [markdown]
# **Observations and variables**

# %%
observations = list(df.index)
variables = list(df.columns)

# %% [markdown]
# **Box and Whisker Plots**

# %%
ax = plt.figure()
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
# Use swarmplot() or stripplot to show the datapoints on top of the boxes:
#plt. figure()
ax = plt.figure()    
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax = sns.stripplot(data=X, color=".25") 
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# **Correlation Matrix**

# %%
ax = sns.heatmap(X.corr(), cmap='RdYlGn_r', linewidths=0.5, annot=True, cbar=False, square=True)
plt.yticks(rotation=0)
ax.tick_params(labelbottom=False,labeltop=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=0);

#X.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
#sns.clustermap(X.corr(), annot=True, fmt='.2f')

# %% [markdown]
# ##**Applying PCA**

# %%
pca = PCA()
Z = pca.fit_transform(X)

# 1(Rosa)->0,  2(Kama)->1, 3(Canadian)->2
idx_Rosa = np.where(y == 0)
idx_Kana = np.where(y == 1)
idx_Canadian = np.where(y == 2)

plt. figure()
plt.scatter(Z[idx_Rosa,0], Z[idx_Rosa,1], c='r', label='Rosa')
plt.scatter(Z[idx_Kana,0], Z[idx_Kana,1], c='g', label='Kana')
plt.scatter(Z[idx_Canadian,0], Z[idx_Canadian,1], c='b', label='Canadian')
plt.legend()
plt.xlabel('$Z_1$')
plt.ylabel('$Z_2$')
# Out:
# Text(0, 0.5, '$Z_2$')

# %% [markdown]
# **Eigenvectors**

# %%
A = pca.components_.T 

plt.scatter(A[:,0],A[:,1],c='r')
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables, A[:, 0], A[:, 1]):
  plt.annotate(label, xy=(x, y), xytext=(-2, 2), textcoords='offset points', ha='right', va='bottom')

# %%
plt.scatter(A[:, 0],A[:, 1], marker='o', c=A[:, 2], s=A[:, 3]*500, cmap=plt.get_cmap('Spectral'))
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables,A[:, 0],A[:, 1]):
  plt.annotate(label,xy=(x, y), xytext=(-20, 20),
      textcoords='offset points', ha='right', va='bottom',
      bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
      arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

# %% [markdown]
# **Scree plot**

# %%
#Eigenvalues
Lambda = pca.explained_variance_ 

#Scree plot
x = np.arange(len(Lambda)) + 1
plt.plot(x,Lambda/sum(Lambda), 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
# Out:
# Text(0, 0.5, 'Explained variance')

# %% [markdown]
# **Explained Variance**

# %%
ell = pca.explained_variance_ratio_
ind = np.arange(len(ell))
plt.bar(ind, ell, align='center', alpha=0.5)
plt.plot(np.cumsum(ell))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %% [markdown]
# **Biplot**

# %%
# 0,1 denote PC1 and PC2; change values for other PCs
A1 = A[:,0] 
A2 = A[:,1]
Z1 = Z[:,0] 
Z2 = Z[:,1]

plt.figure()
plt.xlabel('$Z_1$')
plt.ylabel('$Z_2$')
for i in range(len(A1)):
# arrows project features as vectors onto PC axes
  plt.arrow(0, 0, A1[i]*max(Z1), A2[i]*max(Z2), color='k', width=0.0005, head_width=0.0025)
  plt.text(A1[i]*max(Z1)*1.2, A2[i]*max(Z2)*1.2,variables[i], color='k')

plt.scatter(Z[idx_Rosa,0], Z[idx_Rosa,1], c='r', label='Rosa')
plt.scatter(Z[idx_Kana,0], Z[idx_Kana,1], c='g', label='Kana')
plt.scatter(Z[idx_Canadian,0], Z[idx_Canadian,1], c='b', label='Canadian')
plt.legend(loc='upper left')

# %% [markdown]
# ##**Using PCA Library**

# %%
# !pip3 install pca
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pca in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pca) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pca) (2.27.1)
# Requirement already satisfied: scatterd>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from pca) (1.3.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from pca) (0.13.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pca) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pca) (1.22.4)
# Requirement already satisfied: colourmap>=1.1.11 in /usr/local/lib/python3.10/dist-packages (from pca) (1.1.11)
# Requirement already satisfied: adjusttext in /usr/local/lib/python3.10/dist-packages (from pca) (0.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pca) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pca) (1.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pca) (4.65.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from scatterd>=1.3.1->pca) (0.12.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pca) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pca) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pca) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pca) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->pca) (2.0.12)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pca) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pca) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->pca) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels->pca) (1.16.0)

# %%
from pca import pca
# Initialize and keep all PCs
model = pca()
# Fit transform
out = model.fit_transform(X)
# Out:
# [pca] >Extracting column labels from dataframe.
# [pca] >Extracting row labels from dataframe.
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [7] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [4] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [7] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[4]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]

# %% [markdown]
# **Principal Components**

# %%
out['PC']
# Out:
#           PC1       PC2       PC3       PC4
# 0    2.662980  0.918503 -0.556365  0.742396
# 1    3.523824  0.792355 -0.666968  0.493315
# 2    2.999209  0.864796 -0.979010  0.716692
# 3    2.938568  0.950939 -0.603414  0.531911
# 4    2.931795  0.934446 -1.076467  0.560880
# ..        ...       ...       ...       ...
# 393 -1.418095 -1.224361 -0.293524 -0.672094
# 394 -4.090214 -1.286940  1.954981  1.371510
# 395 -1.544566 -1.245041 -1.915181 -0.322904
# 396 -2.019616 -1.134537  0.603387 -0.465733
# 397 -2.179644 -1.239196  0.781492 -0.159966
#
# [398 rows x 4 columns]

# %% [markdown]
# **Scatter plot**

# %%
model.scatter(label=True, legend=False)
# Out:
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '4 Principal Components explain [98.71%] of the variance'}, xlabel='PC1 (71.5% expl.var)', ylabel='PC2 (12.3% expl.var)'>)

# %% [markdown]
# **Eigenvectors**

# %%
A = out['loadings'].T

# %%
sns.scatterplot(data=A, x="PC1", y="PC2")
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for i in range(A.shape[0]):
 plt.text(x=A.PC1[i]+0.02,y=A.PC2[i]+0.02, s=variables[i],
          fontdict=dict(color='red',size=10),
          bbox=dict(facecolor='yellow',alpha=0.5))

# %% [markdown]
# **Scree Plot**

# %%
VR = out['variance_ratio']
x = np.arange(len(VR)) + 1
plt.plot(x, VR, 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance') 
plt.show()

# %% [markdown]
# **Explained Variance Plot**

# %%
model.plot();

# %% [markdown]
# **Biplot**
#
# A biplot is a graphical representation of multivariate data that displays both observations and variables simultaneously in a single plot. Each observation is represented as a point in a two-dimensional plot, while the variables are represented as arrows or vectors that point in the direction of the greatest variation in the data. The length of the vector indicates the magnitude of the variable, while the angle between two vectors reflects their correlation.

# %%
model.biplot(label=False, legend=False)
# Out:
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '4 Principal Components explain [98.71%] of the variance'}, xlabel='PC1 (71.5% expl.var)', ylabel='PC2 (12.3% expl.var)'>)

# %% [markdown]
# #**Multiclass Classification with PyCaret**
#
# Multiclass classification is a supervised machine learning technique where the goal is to classify instances into one of three or more classes. (Classifying instances into one of two classes is called Binary Classification).

# %% [markdown]
# **Using PyCaret**
#
# PyCaret uses interactive plotting ability. In order to render interactive plots in Google Colab, run the below line of code in your colab notebook. The enable_colab() function in PyCaret is used to install and configure all the necessary dependencies to use PyCaret in Google Colab.

# %%
#For Google Colab only
from pycaret.utils import enable_colab 
enable_colab()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-72-36dff30497de> in <cell line: 2>()
#       1 #For Google Colab only
# ----> 2 from pycaret.utils import enable_colab
#       3 enable_colab()
#
# ImportError: cannot import name 'enable_colab' from 'pycaret.utils' (/usr/local/lib/python3.10/dist-packages/pycaret/utils/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Data Splitting**
#
# In order to demonstrate the predict_model() function on unseen data, a sample of 21 observations has been withheld from the original dataset to be used for predictions. This should not be confused with a train/test split as this particular split is performed to simulate a real life scenario. Another way to think about this is that these 21 records were not available at the time when the machine learning experiment was performed.

# %%
data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (358, 8)
# Unseen Data For Predictions: (40, 8)

# %% [markdown]
# **Setting up the Environment in PyCaret**
#
# The **setup()** function initializes the environment in pycaret and creates the transformation pipeline to prepare the data for modeling and deployment. setup() must be called before executing any other function in pycaret. It takes two mandatory parameters: a pandas dataframe and the name of the target column. All other parameters are optional and are used to customize the pre-processing pipeline.
#
# When setup() is executed, PyCaret's inference algorithm will automatically infer the data types for all features based on certain properties. The data type should be inferred correctly but this is not always the case. To account for this, PyCaret displays a table containing the features and their inferred data types after setup() is executed. If all of the data types are correctly identified enter can be pressed to continue or quit can be typed to end the expriment. Ensuring that the data types are correct is of fundamental importance in PyCaret as it automatically performs a few pre-processing tasks which are imperative to any machine learning experiment. These tasks are performed differently for each data type which means it is very important for them to be correctly configured.

# %%
from pycaret.classification import *
clf = setup(data=data, target='Fuel Economy', train_size=0.7, session_id=123)
# Out:
# <style type="text/css">
# #T_c5227_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c5227" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5227_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c5227_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5227_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5227_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c5227_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5227_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c5227_row1_col1" class="data row1 col1" >Fuel Economy</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c5227_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c5227_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c5227_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c5227_row3_col1" class="data row3 col1" >(358, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c5227_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c5227_row4_col1" class="data row4 col1" >(358, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c5227_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c5227_row5_col1" class="data row5 col1" >(250, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c5227_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c5227_row6_col1" class="data row6 col1" >(108, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c5227_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c5227_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c5227_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_c5227_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c5227_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_c5227_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c5227_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_c5227_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c5227_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_c5227_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c5227_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_c5227_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c5227_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_c5227_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c5227_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_c5227_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c5227_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_c5227_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c5227_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_c5227_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c5227_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_c5227_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c5227_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c5227_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_c5227_row18_col1" class="data row18 col1" >a362</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Once the setup has been succesfully executed it prints the information grid which contains several important pieces of information. Most of the information is related to the pre-processing pipeline which is constructed when setup() is executed. The majority of these features are out of scope for the purposes of this tutorial however a few important things to note at this stage include:
#
# * **session_id** : A pseduo-random number distributed as a seed in all functions for later reproducibility. If no session_id is passed, a random number is automatically generated that is distributed to all functions. In this experiment, the session_id is set as 123 for later reproducibility.
#
# * **Target Type** : Binary or Multiclass. The Target type is automatically detected and shown. There is no difference in how the experiment is performed for Binary or Multiclass problems. All functionalities are identical.
#
# * **Label Encoded** : When the Target variable is of type string (i.e. 'Yes' or 'No') instead of 1 or 0, it automatically encodes the label into 1 and 0 and displays the mapping (0 : No, 1 : Yes) for reference.
#
# * **Original Data** : Displays the original shape of the dataset. In this experiment (189, 8) means 189 samples and 8 features including the class column.
#
# * **Missing Values** : When there are missing values in the original data this will show as True. For this experiment there are no missing values in the dataset.
#
# * **Numeric Features** : The number of features inferred as numeric. In this dataset, 7 out of 8 features are inferred as numeric.
#
# * **Categorical Features** : The number of features inferred as categorical. In this dataset, there are no categorical features.
#
# * **Transformed Train Set** : Displays the shape of the transformed training set. Notice that the original shape of (189, 8) is transformed into (132, 7) for the transformed train set.
#
# * **Transformed Test Set** : Displays the shape of the transformed test/hold-out set. There are 57 samples in test/hold-out set. This split is based on the default value of 70/30 that can be changed using the train_size parameter in setup.
#
# Notice how a few tasks that are imperative to perform modeling are automatically handled such as missing value imputation, categorical encoding etc. Most of the parameters in setup() are optional and used for customizing the pre-processing pipeline.

# %% [markdown]
# **Comparing all Machine Learning Models**

# %%
 #show the best model and their statistics
 best_model = compare_models()
# Out:
# <style type="text/css">
# #T
td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# **Tune K Neighbors Model**

# %%
tuned_knn = tune_model(knn, custom_grid = {'n_neighbors' : np.arange(0,50,1)})
# Out:
# <style type="text/css">
# #T_163a4_row10_col0, #T_163a4_row10_col1, #T_163a4_row10_col2, #T_163a4_row10_col3, #T_163a4_row10_col4, #T_163a4_row10_col5, #T_163a4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_163a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_163a4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_163a4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_163a4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_163a4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_163a4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_163a4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_163a4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_163a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_163a4_row0_col0" class="data row0 col0" >0.9600</td>
#       <td id="T_163a4_row0_col1" class="data row0 col1" >0.9848</td>
#       <td id="T_163a4_row0_col2" class="data row0 col2" >0.9545</td>
#       <td id="T_163a4_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_163a4_row0_col4" class="data row0 col4" >0.9767</td>
#       <td id="T_163a4_row0_col5" class="data row0 col5" >0.8344</td>
#       <td id="T_163a4_row0_col6" class="data row0 col6" >0.8461</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_163a4_row1_col0" class="data row1 col0" >0.9600</td>
#       <td id="T_163a4_row1_col1" class="data row1 col1" >0.9621</td>
#       <td id="T_163a4_row1_col2" class="data row1 col2" >0.9545</td>
#       <td id="T_163a4_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_163a4_row1_col4" class="data row1 col4" >0.9767</td>
#       <td id="T_163a4_row1_col5" class="data row1 col5" >0.8344</td>
#       <td id="T_163a4_row1_col6" class="data row1 col6" >0.8461</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_163a4_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_163a4_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_163a4_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_163a4_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_163a4_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_163a4_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_163a4_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_163a4_row3_col0" class="data row3 col0" >0.8800</td>
#       <td id="T_163a4_row3_col1" class="data row3 col1" >0.9697</td>
#       <td id="T_163a4_row3_col2" class="data row3 col2" >0.9091</td>
#       <td id="T_163a4_row3_col3" class="data row3 col3" >0.9524</td>
#       <td id="T_163a4_row3_col4" class="data row3 col4" >0.9302</td>
#       <td id="T_163a4_row3_col5" class="data row3 col5" >0.5033</td>
#       <td id="T_163a4_row3_col6" class="data row3 col6" >0.5104</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_163a4_row4_col0" class="data row4 col0" >0.9600</td>
#       <td id="T_163a4_row4_col1" class="data row4 col1" >0.9545</td>
#       <td id="T_163a4_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_163a4_row4_col3" class="data row4 col3" >0.9565</td>
#       <td id="T_163a4_row4_col4" class="data row4 col4" >0.9778</td>
#       <td id="T_163a4_row4_col5" class="data row4 col5" >0.7788</td>
#       <td id="T_163a4_row4_col6" class="data row4 col6" >0.7985</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_163a4_row5_col0" class="data row5 col0" >0.9600</td>
#       <td id="T_163a4_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_163a4_row5_col2" class="data row5 col2" >0.9545</td>
#       <td id="T_163a4_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_163a4_row5_col4" class="data row5 col4" >0.9767</td>
#       <td id="T_163a4_row5_col5" class="data row5 col5" >0.8344</td>
#       <td id="T_163a4_row5_col6" class="data row5 col6" >0.8461</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_163a4_row6_col0" class="data row6 col0" >0.8800</td>
#       <td id="T_163a4_row6_col1" class="data row6 col1" >0.9524</td>
#       <td id="T_163a4_row6_col2" class="data row6 col2" >0.9524</td>
#       <td id="T_163a4_row6_col3" class="data row6 col3" >0.9091</td>
#       <td id="T_163a4_row6_col4" class="data row6 col4" >0.9302</td>
#       <td id="T_163a4_row6_col5" class="data row6 col5" >0.5033</td>
#       <td id="T_163a4_row6_col6" class="data row6 col6" >0.5104</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_163a4_row7_col0" class="data row7 col0" >0.8800</td>
#       <td id="T_163a4_row7_col1" class="data row7 col1" >0.8929</td>
#       <td id="T_163a4_row7_col2" class="data row7 col2" >0.9524</td>
#       <td id="T_163a4_row7_col3" class="data row7 col3" >0.9091</td>
#       <td id="T_163a4_row7_col4" class="data row7 col4" >0.9302</td>
#       <td id="T_163a4_row7_col5" class="data row7 col5" >0.5033</td>
#       <td id="T_163a4_row7_col6" class="data row7 col6" >0.5104</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_163a4_row8_col0" class="data row8 col0" >0.9600</td>
#       <td id="T_163a4_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_163a4_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_163a4_row8_col3" class="data row8 col3" >0.9545</td>
#       <td id="T_163a4_row8_col4" class="data row8 col4" >0.9767</td>
#       <td id="T_163a4_row8_col5" class="data row8 col5" >0.8344</td>
#       <td id="T_163a4_row8_col6" class="data row8 col6" >0.8461</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_163a4_row9_col0" class="data row9 col0" >0.8800</td>
#       <td id="T_163a4_row9_col1" class="data row9 col1" >0.9464</td>
#       <td id="T_163a4_row9_col2" class="data row9 col2" >0.9524</td>
#       <td id="T_163a4_row9_col3" class="data row9 col3" >0.9091</td>
#       <td id="T_163a4_row9_col4" class="data row9 col4" >0.9302</td>
#       <td id="T_163a4_row9_col5" class="data row9 col5" >0.5033</td>
#       <td id="T_163a4_row9_col6" class="data row9 col6" >0.5104</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_163a4_row10_col0" class="data row10 col0" >0.9320</td>
#       <td id="T_163a4_row10_col1" class="data row10 col1" >0.9663</td>
#       <td id="T_163a4_row10_col2" class="data row10 col2" >0.9630</td>
#       <td id="T_163a4_row10_col3" class="data row10 col3" >0.9591</td>
#       <td id="T_163a4_row10_col4" class="data row10 col4" >0.9606</td>
#       <td id="T_163a4_row10_col5" class="data row10 col5" >0.7130</td>
#       <td id="T_163a4_row10_col6" class="data row10 col6" >0.7224</td>
#     </tr>
#     <tr>
#       <th id="T_163a4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_163a4_row11_col0" class="data row11 col0" >0.0440</td>
#       <td id="T_163a4_row11_col1" class="data row11 col1" >0.0315</td>
#       <td id="T_163a4_row11_col2" class="data row11 col2" >0.0275</td>
#       <td id="T_163a4_row11_col3" class="data row11 col3" >0.0378</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# **Evaluate K Neighbors Model**

# %%
evaluate_model(tuned_knn)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# **Create Logistic Regression Model**

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_1e349_row10_col0, #T_1e349_row10_col1, #T_1e349_row10_col2, #T_1e349_row10_col3, #T_1e349_row10_col4, #T_1e349_row10_col5, #T_1e349_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1e349" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e349_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1e349_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1e349_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1e349_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1e349_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1e349_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1e349_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e349_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e349_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_1e349_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_1e349_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_1e349_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_1e349_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_1e349_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_1e349_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1e349_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e349_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_1e349_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_1e349_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_1e349_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_1e349_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_1e349_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_1e349_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1e349_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e349_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_1e349_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_1e349_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_1e349_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_1e349_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_1e349_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_1e349_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1e349_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e349_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_1e349_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_1e349_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_1e349_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_1e349_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_1e349_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_1e349_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1e349_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e349_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_1e349_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_1e349_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_1e349_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_1e349_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_1e349_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_1e349_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1e349_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1e349_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_1e349_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_1e349_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_1e349_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_1e349_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_1e349_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_1e349_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1e349_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1e349_row6_col0" class="data row6 col0" >0.9600</td>
#       <td id="T_1e349_row6_col1" class="data row6 col1" >0.9881</td>
#       <td id="T_1e349_row6_col2" class="data row6 col2" >0.9524</td>
#       <td id="T_1e349_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_1e349_row6_col4" class="data row6 col4" >0.9756</td>
#       <td id="T_1e349_row6_col5" class="data row6 col5" >0.8649</td>
#       <td id="T_1e349_row6_col6" class="data row6 col6" >0.8729</td>
#     </tr>
#     <tr>
#       <th id="T_1e349_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1e349_row7_col0" class="data row7 col0" >0.9600</td>
#       <td id="T_1e349_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_
td>
#     </tr>
#   </tbody>
# </table>

# %%
#show the best model and their statistics
best_model_pca = compare_models()
# Out:
# <style type="text/css">
# #T_eb2ca th {
#   text-align: left;
# }
# #T_eb2ca_row0_col0, #T_eb2ca_row0_col2, #T_eb2ca_row0_col3, #T_eb2ca_row0_col4, #T_eb2ca_row1_col0, #T_eb2ca_row1_col1, #T_eb2ca_row1_col2, #T_eb2ca_row1_col3, #T_eb2ca_row1_col4, #T_eb2ca_row1_col5, #T_eb2ca_row1_col6, #T_eb2ca_row1_col7, #T_eb2ca_row2_col0, #T_eb2ca_row2_col1, #T_eb2ca_row2_col2, #T_eb2ca_row2_col3, #T_eb2ca_row2_col4, #T_eb2ca_row2_col5, #T_eb2ca_row2_col6, #T_eb2ca_row2_col7, #T_eb2ca_row3_col0, #T_eb2ca_row3_col1, #T_eb2ca_row3_col2, #T_eb2ca_row3_col3, #T_eb2ca_row3_col4, #T_eb2ca_row3_col5, #T_eb2ca_row3_col6, #T_eb2ca_row3_col7, #T_eb2ca_row4_col0, #T_eb2ca_row4_col1, #T_eb2ca_row4_col2, #T_eb2ca_row4_col3, #T_eb2ca_row4_col4, #T_eb2ca_row4_col5, #T_eb2ca_row4_col6, #T_eb2ca_row4_col7, #T_eb2ca_row5_col0, #T_eb2ca_row5_col1, #T_eb2ca_row5_col2, #T_eb2ca_row5_col3, #T_eb2ca_row5_col4, #T_eb2ca_row5_col5, #T_eb2ca_row5_col6, #T_eb2ca_row5_col7, #T_eb2ca_row6_col0, #T_eb2ca_row6_col1, #T_eb2ca_row6_col2, #T_eb2ca_row6_col3, #T_eb2ca_row6_col4, #T_eb2ca_row6_col5, #T_eb2ca_row6_col6, #T_eb2ca_row6_col7, #T_eb2ca_row7_col0, #T_eb2ca_row7_col1, #T_eb2ca_row7_col2, #T_eb2ca_row7_col3, #T_eb2ca_row7_col4, #T_eb2ca_row7_col5, #T_eb2ca_row7_col6, #T_eb2ca_row7_col7, #T_eb2ca_row8_col0, #T_eb2ca_row8_col1, #T_eb2ca_row8_col3, #T_eb2ca_row8_col4, #T_eb2ca_row8_col5, #T_eb2ca_row8_col6, #T_eb2ca_row8_col7, #T_eb2ca_row9_col0, #T_eb2ca_row9_col1, #T_eb2ca_row9_col2, #T_eb2ca_row9_col3, #T_eb2ca_row9_col4, #T_eb2ca_row9_col5, #T_eb2ca_row9_col6, #T_eb2ca_row9_col7, #T_eb2ca_row10_col0, #T_eb2ca_row10_col1, #T_eb2ca_row10_col2, #T_eb2ca_row10_col3, #T_eb2ca_row10_col5, #T_eb2ca_row10_col6, #T_eb2ca_row10_col7, #T_eb2ca_row11_col0, #T_eb2ca_row11_col1, #T_eb2ca_row11_col2, #T_eb2ca_row11_col3, #T_eb2ca_row11_col4, #T_eb2ca_row11_col5, #T_eb2ca_row11_col6, #T_eb2ca_row11_col7, #T_eb2ca_row12_col0, #T_eb2ca_row12_col1, #T_eb2ca_row12_col2, #T_eb2ca_row12_col3, #T_eb2ca_row12_col4, #T_eb2ca_row12_col5, #T_eb2ca_row12_col6, #T_eb2ca_row12_col7, #T_eb2ca_row13_col0, #T_eb2ca_row13_col1, #T_eb2ca_row13_col2, #T_eb2ca_row13_col3, #T_eb2ca_row13_col4, #T_eb2ca_row13_col5, #T_eb2ca_row13_col6, #T_eb2ca_row13_col7, #T_eb2ca_row14_col0, #T_eb2ca_row14_col1, #T_eb2ca_row14_col2, #T_eb2ca_row14_col4, #T_eb2ca_row14_col5, #T_eb2ca_row14_col6, #T_eb2ca_row14_col7 {
#   text-align: left;
# }
# #T_eb2ca_row0_col1, #T_eb2ca_row0_col5, #T_eb2ca_row0_col6, #T_eb2ca_row0_col7, #T_eb2ca_row8_col2, #T_eb2ca_row10_col4, #T_eb2ca_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_eb2ca_row0_col8, #T_eb2ca_row1_col8, #T_eb2ca_row2_col8, #T_eb2ca_row3_col8, #T_eb2ca_row4_col8, #T_eb2ca_row5_col8, #T_eb2ca_row6_col8, #T_eb2ca_row7_col8, #T_eb2ca_row8_col8, #T_eb2ca_row10_col8, #T_eb2ca_row11_col8, #T_eb2ca_row12_col8, #T_eb2ca_row13_col8, #T_eb2ca_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_eb2ca_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_eb2ca" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb2ca_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eb2ca_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_eb2ca_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_eb2ca_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_eb2ca_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_eb2ca_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_eb2ca_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_eb2ca_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_eb2ca_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb2ca_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_eb2ca_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_eb2ca_row0_col1" class="data row0 col1" >0.9640</td>
#       <td id="T_eb2ca_row0_col2" class="data row0 col2" >0.9855</td>
#       <td id="T_eb2ca_row0_col3" class="data row0 col3" >0.9835</td>
#       <td id="T_eb2ca_row0_col4" class="data row0 col4" >0.9761</td>
#       <td id="T_eb2ca_row0_col5" class="data row0 col5" >0.9794</td>
#       <td id="T_eb2ca_row0_col6" class="data row0 col6" >0.8336</td>
#       <td id="T_eb2ca_row0_col7" class="data row0 col7" >0.8457</td>
#       <td id="T_eb2ca_row0_col8" class="data row0 col8" >0.4820</td>
#     </tr>
#     <tr>
#       <th id="T_eb2ca_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_eb2ca_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_eb2ca_row1_col1" class="data row1 col1" >0.9496</td>
#       <td id="T_eb2ca_row1_col2" class="data row1 col2" >0.9862</td>
#       <td id="T_eb2ca_row1_col3" class="data row1 col3" >0.9877</td>
#       <td id="T_eb2ca_row1_col4" class="data row1 col4" >0.9568</td>
#       <td id="T_eb2ca_row1_col5" class="data row1 col5" >0.9716</td>
#       <td id="T_eb2ca_row1_col6" class="data row1 col6" >0.7486</td>
#       <td id="T_eb2ca_row1_col7" class="data row1 col7" >0.7679</td>
#       <td id="T_eb2ca_row1_col8" class="data row1 col8" >0.5940</td>
#     </tr>
#     <tr>
#       <th id="T_eb2ca_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_eb2ca_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_eb2ca_row2_col1" class="data row2 col1" >0.9496</td>
#       <td id="T_eb2ca_row2_col2" class="data row2 col2" >0.9806</td>
#       <td id="T_eb2ca_row2_col3" class="data row2 col3" >0.9752</td>
#       <td id="T_eb2ca_row2_col4" class="data row2 col4" >0.9678</td>
#       <td id="T_eb2ca_row2_col5" class="data row2 col5" >0.9711</td>
#       <td id="T_eb2ca_row2_col6" class="data row2 col6" >0.7701</td>
#       <td id="T_eb2ca_row2_col7" class="data row2 col7" >0.7818</td>
#       <td id="T_eb2ca_row2_col8" class="data row2 col8" >0.2380</td>
#     </tr>
#     <tr>
#       <th id="T_eb2ca_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_eb2ca_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T
row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_9e863_row4_col4" class="data row4 col4" >0.9565</td>
#       <td id="T_9e863_row4_col5" class="data row4 col5" >0.7586</td>
#       <td id="T_9e863_row4_col6" class="data row4 col6" >0.7817</td>
#     </tr>
#     <tr>
#       <th id="T_9e863_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9e863_row5_col0" class="data row5 col0" >0.9643</td>
#       <td id="T_9e863_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_9e863_row5_col2" class="data row5 col2" >0.9583</td>
#       <td id="T_9e863_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_9e863_row5_col4" class="data row5 col4" >0.9787</td>
#       <td id="T_9e863_row5_col5" class="data row5 col5" >0.8679</td>
#       <td id="T_9e863_row5_col6" class="data row5 col6" >0.8756</td>
#     </tr>
#     <tr>
#       <th id="T_9e863_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9e863_row6_col0" class="data row6 col0" >0.8929</td>
#       <td id="T_9e863_row6_col1" class="data row6 col1" >0.9688</td>
#       <td id="T_9e863_row6_col2" class="data row6 col2" >0.8750</td>
#       <td id="T_9e863_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_9e863_row6_col4" class="data row6 col4" >0.9333</td>
#       <td id="T_9e863_row6_col5" class="data row6 col5" >0.6667</td>
#       <td id="T_9e863_row6_col6" class="data row6 col6" >0.7071</td>
#     </tr>
#     <tr>
#       <th id="T_9e863_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9e863_row7_col0" class="data row7 col0" >0.9286</td>
#       <td id="T_9e863_row7_col1" class="data row7 col1" >0.9792</td>
#       <td id="T_9e863_row7_col2" class="data row7 col2" >0.9583</td>
#       <td id="T_9e863_row7_col3" class="data row7 col3" >0.9583</td>
#       <td id="T_9e863_row7_col4" class="data row7 col4" >0.9583</td>
#       <td id="T_9e863_row7_col5" class="data row7 col5" >0.7083</td>
#       <td id="T_9e863_row7_col6" class="data row7 col6" >0.7083</td>
#     </tr>
#     <tr>
#       <th id="T_9e863_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9e863_row8_col0" class="data row8 col0" >0.9630</td>
#       <td id="T_9e863_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_9e863_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_9e863_row8_col3" class="data row8 col3" >0.9600</td>
#       <td id="T_9e863_row8_col4" class="data row8 col4" >0.9796</td>
#       <td id="T_9e863_row8_col5" class="data row8 col5" >0.7805</td>
#       <td id="T_9e863_row8_col6" class="data row8 col6" >0.8000</td>
#     </tr>
#     <tr>
#       <th id="T_9e863_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9e863_row9_col0" class="data row9 col0" >0.9259</td>
#       <td id="T_9e863_row9_col1" class="data row9 col1" >0.9583</td>
#       <td id="T_9e863_row9_col2" class="data row9 col2" >0.9583</td>
#       <td id="T_9e863_row9_col3" class="data row9 col3" >0.9583</td>
#       <td id="T_9e863_row9_col4" class="data row9 col4" >0.9583</td>
#       <td id="T_9e863_row9_col5" class="data row9 col5" >0.6250</td>
#       <td id="T_9e863_row9_col6" class="data row9 col6" >0.6250</td>
#     </tr>
#     <tr>
#       <th id="T_9e863_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9e863_row10_col0" class="data row10 col0" >0.9389</td>
#       <td id="T_9e863_row10_col1" class="data row10 col1" >0.9845</td>
#       <td id="T_9e863_row10_col2" class="data row10 col2" >0.9585</td>
#       <td id="T_9e863_row10_col3" class="data row10 col3" >0.9720</td>
#       <td id="T_9e863_row10_col4" class="data row10 col4" >0.9643</td>
#       <td id="T_9e863_row10_col5" class="data row10 col5" >0.7370</td>
#       <td id="T_9e863_row10_col6" class="data row10 col6" >0.7528</td>
#     </tr>
#     <tr>
#       <th id="T_9e863_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9e863_row11_col0" class="data row11 col0" >0.0229</td>
#       <td id="T_9e863_row11_col1" class="data row11 col1" >0.0160</td>
#       <td id="T_9e863_row11_col2" class="data row11 col2" >0.0373</td>
#       <td id="T_9e863_row11_col3" class="data row11 col3" >0.0252</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
tuned_best_model_pca
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False)

# %% [markdown]
# **Evaluate the Best Model**
#
# One way to analyze the performance of models is to use the evaluate_model() function which displays a user interface for all of the available plots for a given model. It internally uses the plot_model() function.

# %%
evaluate_model(tuned_best_model_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# **Note:** The AUC metric is not available for Multiclass classification however the column will still be shown with zero values to maintain consistency between the Binary Classification and Multiclass Classification display grids.

# %% [markdown]
# #**Explainable AI with Shapley values**
#
# Shapley values are a widely used approach from cooperative game theory that come with desirable properties.
#
# SHAP is a Python library for model interpretation and feature importance analysis, and it provides a variety of tools for explaining the output of machine learning models. The library is based on the Shapley value, a concept from cooperative game theory that assigns a value to each player in a game based on their contribution to the overall outcome.

# %%
# !pip3 install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
#import the SHAP (SHapley Additive exPlanations) library
import shap

# %%
rf_pca = create_model('rf')
# Out:
# <style type="text/css">
# #T_e772c_row10_col0, #T_e772c_row10_col1, #T_e772c_row10_col2, #T_e772c_row10_col3, #T_e772c_row10_col4, #T_e772c_row10_col5, #T_e772c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e772c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e772c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e772c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e772c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e772c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e772c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e772c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e772c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e772c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e772c_row0_col0" class="data row0 col0" >0.9643</td>
#       <td id="T_e772c_row0_col1" class="data row0 col1" >0.9867</td>
#       <td id="T_e772c_row0_col2" class="data row0 col2" >0.9600</td>
#       <td id="T_e772c_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_e772c_row0_col4" class="data row0 col4" >0.9796</td>
#       <td id="T_e772c_row0_col5" class="data row0 col5" >0.8372</td>
#       <td id="T_e772c_row0_col6" class="data row0 col6" >0.8485</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e772c_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_e772c_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_e772c_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_e772c_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_e772c_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_e772c_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_e772c_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e772c_row2_col0" class="data row2 col0" >0.9286</td>
#       <td id="T_e772c_row2_col1" class="data row2 col1" >0.9896</td>
#       <td id="T_e772c_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_e772c_row2_col3" class="data row2 col3" >0.9231</td>
#       <td id="T_e772c_row2_col4" class="data row2 col4" >0.9600</td>
#       <td id="T_e772c_row2_col5" class="data row2 col5" >0.6316</td>
#       <td id="T_e772c_row2_col6" class="data row2 col6" >0.6794</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e772c_row3_col0" class="data row3 col0" >0.9286</td>
#       <td id="T_e772c_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_e772c_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_e772c_row3_col3" class="data row3 col3" >0.9231</td>
#       <td id="T_e772c_row3_col4" class="data row3 col4" >0.9600</td>
#       <td id="T_e772c_row3_col5" class="data row3 col5" >0.6316</td>
#       <td id="T_e772c_row3_col6" class="data row3 col6" >0.6794</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e772c_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_e772c_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_e772c_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_e772c_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_e772c_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_e772c_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_e772c_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e772c_row5_col0" class="data row5 col0" >0.9643</td>
#       <td id="T_e772c_row5_col1" class="data row5 col1" >0.9896</td>
#       <td id="T_e772c_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_e772c_row5_col3" class="data row5 col3" >0.9600</td>
#       <td id="T_e772c_row5_col4" class="data row5 col4" >0.9796</td>
#       <td id="T_e772c_row5_col5" class="data row5 col5" >0.8372</td>
#       <td id="T_e772c_row5_col6" class="data row5 col6" >0.8485</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e772c_row6_col0" class="data row6 col0" >0.8929</td>
#       <td id="T_e772c_row6_col1" class="data row6 col1" >0.9688</td>
#       <td id="T_e772c_row6_col2" class="data row6 col2" >0.9583</td>
#       <td id="T_e772c_row6_col3" class="data row6 col3" >0.9200</td>
#       <td id="T_e772c_row6_col4" class="data row6 col4" >0.9388</td>
#       <td id="T_e772c_row6_col5" class="data row6 col5" >0.5116</td>
#       <td id="T_e772c_row6_col6" class="data row6 col6" >0.5185</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e772c_row7_col0" class="data row7 col0" >0.9286</td>
#       <td id="T_e772c_row7_col1" class="data row7 col1" >0.9688</td>
#       <td id="T_e772c_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_e772c_row7_col3" class="data row7 col3" >0.9231</td>
#       <td id="T_e772c_row7_col4" class="data row7 col4" >0.9600</td>
#       <td id="T_e772c_row7_col5" class="data row7 col5" >0.6316</td>
#       <td id="T_e772c_row7_col6" class="data row7 col6" >0.6794</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e772c_row8_col0" class="data row8 col0" >0.9630</td>
#       <td id="T_e772c_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_e772c_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_e772c_row8_col3" class="data row8 col3" >0.9600</td>
#       <td id="T_e772c_row8_col4" class="data row8 col4" >0.9796</td>
#       <td id="T_e772c_row8_col5" class="data row8 col5" >0.7805</td>
#       <td id="T_e772c_row8_col6" class="data row8 col6" >0.8000</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e772c_row9_col0" class="data row9 col0" >0.9259</td>
#       <td id="T_e772c_row9_col1" class="data row9 col1" >0.9583</td>
#       <td id="T_e772c_row9_col2" class="data row9 col2" >0.9583</td>
#       <td id="T_e772c_row9_col3" class="data row9 col3" >0.9583</td>
#       <td id="T_e772c_row9_col4" class="data row9 col4" >0.9583</td>
#       <td id="T_e772c_row9_col5" class="data row9 col5" >0.6250</td>
#       <td id="T_e772c_row9_col6" class="data row9 col6" >0.6250</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e772c_row10_col0" class="data row10 col0" >0.9496</td>
#       <td id="T_e772c_row10_col1" class="data row10 col1" >0.9862</td>
#       <td id="T_e772c_row10_col2" class="data row10 col2" >0.9877</td>
#       <td id="T_e772c_row10_col3" class="data row10 col3" >0.9568</td>
#       <td id="T_e772c_row10_col4" class="data row10 col4" >0.9716</td>
#       <td id="T_e772c_row10_col5" class="data row10 col5" >0.7486</td>
#       <td id="T_e772c_row10_col6" class="data row10 col6" >0.7679</td>
#     </tr>
#     <tr>
#       <th id="T_e772c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e772c_row11_col0" class="data row11 col0" >0.0329</td>
#       <td id="T_e772c_row11_col1" class="data row11 col1" >0.0147</td>
#       <td id="T_e772c_row11_col2" class="data row11 col2" >0.0188</td>
#       <td id="T_e772c_row11_col3" class="data row11 col3" >0.0322</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tuned_rf_pca = tune_model(rf_pca)
# Out:
# <style type="text/css">
# #T_b9f04_row10_col0, #T_b9f04_row10_col1, #T_b9f04_row10_col2, #T_b9f04_row10_col3, #T_b9f04_row10_col4, #T_b9f04_row10_col5, #T_b9f04_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b9f04" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9f04_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b9f04_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b9f04_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b9f04_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b9f04_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b9f04_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b9f04_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9f04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9f04_row0_col0" class="data row0 col0" >0.9286</td>
#       <td id="T_b9f04_row0_col1" class="data row0 col1" >0.9867</td>
#       <td id="T_b9f04_row0_col2" class="data row0 col2" >0.9600</td>
#       <td id="T_b9f04_row0_col3" class="data row0 col3" >0.9600</td>
#       <td id="T_b9f04_row0_col4" class="data row0 col4" >0.9600</td>
#       <td id="T_b9f04_row0_col5" class="data row0 col5" >0.6267</td>
#       <td id="T_b9f04_row0_col6" class="data row0 col6" >0.6267</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9f04_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_b9f04_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_b9f04_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_b9f04_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_b9f04_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_b9f04_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_b9f04_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9f04_row2_col0" class="data row2 col0" >0.9286</td>
#       <td id="T_b9f04_row2_col1" class="data row2 col1" >0.9896</td>
#       <td id="T_b9f04_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_b9f04_row2_col3" class="data row2 col3" >0.9231</td>
#       <td id="T_b9f04_row2_col4" class="data row2 col4" >0.9600</td>
#       <td id="T_b9f04_row2_col5" class="data row2 col5" >0.6316</td>
#       <td id="T_b9f04_row2_col6" class="data row2 col6" >0.6794</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9f04_row3_col0" class="data row3 col0" >0.9643</td>
#       <td id="T_b9f04_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_b9f04_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_b9f04_row3_col3" class="data row3 col3" >0.9600</td>
#       <td id="T_b9f04_row3_col4" class="data row3 col4" >0.9796</td>
#       <td id="T_b9f04_row3_col5" class="data row3 col5" >0.8372</td>
#       <td id="T_b9f04_row3_col6" class="data row3 col6" >0.8485</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9f04_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_b9f04_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_b9f04_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_b9f04_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_b9f04_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_b9f04_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_b9f04_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9f04_row5_col0" class="data row5 col0" >0.9643</td>
#       <td id="T_b9f04_row5_col1" class="data row5 col1" >0.9948</td>
#       <td id="T_b9f04_row5_col2" class="data row5 col2" >0.9583</td>
#       <td id="T_b9f04_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_b9f04_row5_col4" class="data row5 col4" >0.9787</td>
#       <td id="T_b9f04_row5_col5" class="data row5 col5" >0.8679</td>
#       <td id="T_b9f04_row5_col6" class="data row5 col6" >0.8756</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b9f04_row6_col0" class="data row6 col0" >0.9286</td>
#       <td id="T_b9f04_row6_col1" class="data row6 col1" >0.9688</td>
#       <td id="T_b9f04_row6_col2" class="data row6 col2" >0.9583</td>
#       <td id="T_b9f04_row6_col3" class="data row6 col3" >0.9583</td>
#       <td id="T_b9f04_row6_col4" class="data row6 col4" >0.9583</td>
#       <td id="T_b9f04_row6_col5" class="data row6 col5" >0.7083</td>
#       <td id="T_b9f04_row6_col6" class="data row6 col6" >0.7083</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b9f04_row7_col0" class="data row7 col0" >0.8571</td>
#       <td id="T_b9f04_row7_col1" class="data row7 col1" >0.9479</td>
#       <td id="T_b9f04_row7_col2" class="data row7 col2" >0.9167</td>
#       <td id="T_b9f04_row7_col3" class="data row7 col3" >0.9167</td>
#       <td id="T_b9f04_row7_col4" class="data row7 col4" >0.9167</td>
#       <td id="T_b9f04_row7_col5" class="data row7 col5" >0.4167</td>
#       <td id="T_b9f04_row7_col6" class="data row7 col6" >0.4167</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b9f04_row8_col0" class="data row8 col0" >0.9259</td>
#       <td id="T_b9f04_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_b9f04_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_b9f04_row8_col3" class="data row8 col3" >0.9231</td>
#       <td id="T_b9f04_row8_col4" class="data row8 col4" >0.9600</td>
#       <td id="T_b9f04_row8_col5" class="data row8 col5" >0.4706</td>
#       <td id="T_b9f04_row8_col6" class="data row8 col6" >0.5547</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b9f04_row9_col0" class="data row9 col0" >0.9630</td>
#       <td id="T_b9f04_row9_col1" class="data row9 col1" >0.9931</td>
#       <td id="T_b9f04_row9_col2" class="data row9 col2" >0.9583</td>
#       <td id="T_b9f04_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_b9f04_row9_col4" class="data row9 col4" >0.9787</td>
#       <td id="T_b9f04_row9_col5" class="data row9 col5" >0.8364</td>
#       <td id="T_b9f04_row9_col6" class="data row9 col6" >0.8478</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b9f04_row10_col0" class="data row10 col0" >0.9460</td>
#       <td id="T_b9f04_row10_col1" class="data row10 col1" >0.9881</td>
#       <td id="T_b9f04_row10_col2" class="data row10 col2" >0.9752</td>
#       <td id="T_b9f04_row10_col3" class="data row10 col3" >0.9641</td>
#       <td id="T_b9f04_row10_col4" class="data row10 col4" >0.9692</td>
#       <td id="T_b9f04_row10_col5" class="data row10 col5" >0.7395</td>
#       <td id="T_b9f04_row10_col6" class="data row10 col6" >0.7558</td>
#     </tr>
#     <tr>
#       <th id="T_b9f04_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b9f04_row11_col0" class="data row11 col0" >0.0400</td>
#       <td id="T_b9f04_row11_col1" class="data row11 col1" >0.0162</td>
#       <td id="T_b9f04_row11_col2" class="data row11 col2" >0.0275</td>
#       <td id="T_b9f04_row11_col3" class="data row11 col3" >0.0329</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# **SHAP Summary Plot**
#
# Rather than using a typical feature importance bar chart, we use a density scatter plot of SHAP values for each feature to identify how much impact each feature has on the model output for individuals in the validation dataset. Features are sorted by the sum of the SHAP value magnitudes across all samples.

# %%
interpret_model(tuned_rf_pca, plot='summary')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-109-490d48e71867> in <cell line: 1>()
# ----> 1 interpret_model(tuned_rf_pca, plot='summary')
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/functional.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1935     """
#    1936
# -> 1937     return _CURRENT_EXPERIMENT.interpret_model(
#    1938         estimator=estimator,
#    1939         plot=plot,
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/oop.py in interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2281         """
#    2282
# -> 2283         return super().interpret_model(
#    2284             estimator=estimator,
#    2285             plot=plot,
#
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py in interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4031         # checking if shap available
#    4032         if plot in ["summary", "correlation", "reason"]:
# -> 4033             _check_soft_dependencies("shap", extra="analysis", severity="error")
#    4034             import shap
#    4035
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/_dependencies.py in _check_soft_dependencies(package, severity, extra, install_name)
#     150         if severity == "error":
#     151             logger.exception(f"{msg}")
# --> 152             raise ModuleNotFoundError(msg)
#     153         elif severity == "warning":
#     154             logger.warning(f"{msg}")
#
# ModuleNotFoundError:
# 'shap' is a soft dependency and not included in the pycaret installation. Please run: `pip install shap` to install.
# Alternately, you can install this by running `pip install pycaret[analysis]`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#explainer = shap.TreeExplainer(tuned_rf_pca)
#X = df.drop('class', axis=1)
#shap_values = explainer.shap_values(X)
#shap.summary_plot(shap_values, X)

# %% [markdown]
# **Visualize a single prediction**

# %%
interpret_model(tuned_rf_pca, plot='reason', observation=32)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-111-4ce3ca0eb0ec> in <cell line: 1>()
# ----> 1 interpret_model(tuned_rf_pca, plot='reason', observation=32)
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/functional.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1935     """
#    1936
# -> 1937     return _CURRENT_EXPERIMENT.interpret_model(
#    1938         estimator=estimator,
#    1939         plot=plot,
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/oop.py in interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2281         """
#    2282
# -> 2283         return super().interpret_model(
#    2284             estimator=estimator,
#    2285             plot=plot,
#
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py in interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4031         # checking if shap available
#    4032         if plot in ["summary", "correlation", "reason"]:
# -> 4033             _check_soft_dependencies("shap", extra="analysis", severity="error")
#    4034             import shap
#    4035
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/_dependencies.py in _check_soft_dependencies(package, severity, extra, install_name)
#     150         if severity == "error":
#     151             logger.exception(f"{msg}")
# --> 152             raise ModuleNotFoundError(msg)
#     153         elif severity == "warning":
#     154             logger.warning(f"{msg}")
#
# ModuleNotFoundError:
# 'shap' is a soft dependency and not included in the pycaret installation. Please run: `pip install shap` to install.
# Alternately, you can install this by running `pip install pycaret[analysis]`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# From the above the plot, we can seethe "base value," which is defined as the mean predicted target; and f(x), which is the prediction for a selected observation (i.e. observation number 32). The red-colored features increased the predicted value, while the blue-colored features decreased it. The size of each feature (i.e. Principal Component) indicates the impact it has on the model.

# %% [markdown]
# **Visualize many predictions**

# %%
interpret_model(tuned_rf_pca, plot='reason')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-112-14cf2241130c> in <cell line: 1>()
# ----> 1 interpret_model(tuned_rf_pca, plot='reason')
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/functional.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1935     """
#    1936
# -> 1937     return _CURRENT_EXPERIMENT.interpret_model(
#    1938         estimator=estimator,
#    1939         plot=plot,
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/oop.py in interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2281         """
#    2282
# -> 2283         return super().interpret_model(
#    2284             estimator=estimator,
#    2285             plot=plot,
#
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py in interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4031         # checking if shap available
#    4032         if plot in ["summary", "correlation", "reason"]:
# -> 4033             _check_soft_dependencies("shap", extra="analysis", severity="error")
#    4034             import shap
#    4035
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/_dependencies.py in _check_soft_dependencies(package, severity, extra, install_name)
#     150         if severity == "error":
#     151             logger.exception(f"{msg}")
# --> 152             raise ModuleNotFoundError(msg)
#     153         elif severity == "warning":
#     154             logger.warning(f"{msg}")
#
# ModuleNotFoundError:
# 'shap' is a soft dependency and not included in the pycaret installation. Please run: `pip install shap` to install.
# Alternately, you can install this by running `pip install pycaret[analysis]`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
